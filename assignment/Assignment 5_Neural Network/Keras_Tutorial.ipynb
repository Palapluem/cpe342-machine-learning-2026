# %%
import tensorflow as tf
print('TensorFlow Version: ', tf.__version__)
print('Keras Version, ', tf.keras.__version__)
# Out:
# TensorFlow Version:  2.21.0
# Keras Version,  3.15.1

# %% [markdown]
# ## Load and Preprocess the Data
# The MNIST dataset is built into Keras, so we can load it directly

# %%
from tensorflow.keras import layers, models

(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()

# Normalize pixel values to be between 0 and 1
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# ## Define the Model Architecture
# We'll build a simple neural network using the Sequential API
# * We create a Sequential model.
# * Add a fully connected (Dense) layer with 128 units and ReLU activation.
# * Add another Dense layer with 10 units (for classification) and a Softmax activation.

# %%
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])
# Out:
# C:\Users\Admin\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Compile the Model
# Compile the model by specifying the optimizer, loss function, and evaluation metric
# * `model.compile(...)`: This method configures the model for training.
# * `optimizer='adam'`: This specifies the optimization algorithm used to update the model's weights during training. 'adam' is a popular and effective choice.
# * `loss='sparse_categorical_crossentropy'`: This defines the loss function, which measures how well the model is performing. 'sparse_categorical_crossentropy' is suitable for multi-class classification problems like this one, where the labels are integers.
# * `metrics=['accuracy']`: This specifies the metric(s) used to evaluate the model's performance during training and testing. 'accuracy' measures the proportion of correctly classified samples.

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# ## Train the Model
# Train the model using the training dataset

# %%
model.fit(train_images, train_labels, epochs=5, validation_split=0.2)
# Out:
# Epoch 1/5
#    1/1500 ━━━━━━━━━━━━━━━━━━━━ 22:30 901ms/step - accuracy: 0.0625 - loss: 2.3197
#   26/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.5180 - loss: 1.6237
#   54/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6597 - loss: 1.2090
#   82/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7256 - loss: 0.9914
#  105/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7524 - loss: 0.8863
#  128/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7739 - loss: 0.8054
#  153/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7896 - loss: 0.7452
#  179/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8050 - loss: 0.6959
#  209/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8165 - loss: 0.6523
#  238/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8258 - loss: 0.6166
#  262/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8349 - loss: 0.5846
#  286/1500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8408 - loss: 0.5615
# ...

# %% [markdown]
# ## Evaluate the Model
# After training, evaluate the model on the test dataset

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f'Test accuracy: {test_acc}')
# Out:
#   1/313 ━━━━━━━━━━━━━━━━━━━━ 35s 114ms/step - accuracy: 0.9688 - loss: 0.0497
#  40/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9695 - loss: 0.0983
#  82/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9630 - loss: 0.1151
# 125/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9645 - loss: 0.1141
# 161/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9668 - loss: 0.1091
# 198/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9681 - loss: 0.1017
# 245/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9727 - loss: 0.0890
# 292/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9753 - loss: 0.0803
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9752 - loss: 0.0808
# Test accuracy: 0.9751999974250793

# %%
# Verification: Sample Predictions vs Ground Truth
import numpy as np
sample_preds = model.predict(test_images[:5])
pred_classes = np.argmax(sample_preds, axis=1)
print('Predicted Classes:', pred_classes)
print('Ground Truth    :', test_labels[:5])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Predicted Classes: [7 2 1 0 4]
# Ground Truth    : [7 2 1 0 4]
